# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/NLP-MCD/blob/main/09-LSAToyExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio LSA
#
# Completar la información:
#
# https://unisonmx-my.sharepoint.com/:x:/g/personal/mauricio_toledo_unison_mx/Ee5h2okpXktHk-AqFWKeHxQBY5W5mYHq6mWIdVG9FmQznA?e=mlHJYn

# %%
import pandas as pd

df = pd.read_csv('peliculas.csv', encoding='latin1', index_col=0)
df
# Out:
#        Oppenheimer (2023)  Barbie (2023)  Dune (2021)  \
# est1                  NaN            NaN          NaN
# est2                  NaN            NaN          NaN
# est3                  NaN            NaN          NaN
# est4                  NaN            NaN          NaN
# est5                  NaN            NaN          NaN
# est6                  NaN            NaN          NaN
# est7                  NaN            NaN          NaN
# est8                  NaN            NaN          NaN
# est9                  NaN            NaN          NaN
# est10                 NaN            NaN          NaN
#
#        Spider-Man: No Way Home (2021)  Top Gun: Maverick (2022)  \
# est1                              NaN                       NaN
# est2                              NaN                       NaN
# est3                              NaN                       NaN
# est4                              NaN                       NaN
# ...

# %%
names = df.index.to_list()

# %%
movies = df.columns.to_list()
movies
# Out:
# ['Oppenheimer (2023)',
#  'Barbie (2023)',
#  'Dune (2021)',
#  'Spider-Man: No Way Home (2021)',
#  'Top Gun: Maverick (2022)',
#  'Black Panther: Wakanda Forever (2022)',
#  'Mission: Impossible \x96 Dead Reckoning Part One (2023)',
#  'Everything Everywhere All at Once (2022)',
#  'The Batman (2022)',
#  'Encanto (2021)']

# %% [markdown]
# Dividimos en $k$ grupos las películas

# %%
from sklearn.decomposition import TruncatedSVD

k = 3

svd = TruncatedSVD(n_components=k)
svd.fit(values)
mat = svd.transform(values)

# %% [markdown]
# La matriz que contiene la afinidad de cada persona con cada uno de los $k$ grupos de películas.

# %%
mat.shape
# Out:
# (20, 3)

# %%
users_groups = np.argmax(mat, axis=1)
pd.DataFrame(users_groups, index=names, columns=['Group']).sort_values('Group')
# Out:
#        Group
# est1       0
# est8       0
# est7       0
# est6       0
# est5       0
# est4       0
# est3       0
# est2       0
# est1       0
# est10      0
# est9       0
# est8       0
# est7       0
# est6       0
# est5       0
# est4       0
# est3       0
# est2       0
# est9       0
# est10      0

# %% [markdown]
# La matriz que contiene la afinidad de cada película con cada grupo.

# %%
svd.components_.shape
# Out:
# (3, 10)

# %%
movie_groups = np.argmax(svd.components_, axis=0)
pd.DataFrame(movie_groups, index=movies, columns=['Group']).sort_values('Group')
# Out:
#                                                     Group
# Oppenheimer (2023)                                      0
# Barbie (2023)                                           0
# Dune (2021)                                             0
# Black Panther: Wakanda Forever (2022)                   0
# Everything Everywhere All at Once (2022)                0
# Encanto (2021)                                          0
# Spider-Man: No Way Home (2021)                          1
# Top Gun: Maverick (2022)                                1
# Mission: Impossible  Dead Reckoning Part One (...      1
# The Batman (2022)                                       2
